# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
p = np.linspace(0, 0.75, 76)

# %%
plt.plot(p, p)
plt.plot(p, -np.log(1 - p))
plt.plot(p, 0.7 * ((1 - p) ** (-1 / 0.7) - 1))
plt.plot(p, -0.75 * np.log(1 - p * 4 / 3))
plt.xlim(0, 0.75)
plt.show()
# Out:
# /home/greg/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: RuntimeWarning: divide by zero encountered in log
